# %%
import boto3
import pandas as pd

# %%
s3 = boto3.resource(
    service_name='s3',
    region_name='us-east-1'
)

# %%
list_df = []
bucket = s3.Bucket('openaq-fetches')
objs = list(bucket.objects.filter(Prefix='realtime/2021-02-22/'))
for i in range(0, len(objs)):
    print(objs[i].key)
    s3file_obj = s3.Bucket('openaq-fetches').Object(objs[i].key).get()
    df = pd.read_json(s3file_obj['Body'], lines=True)
    print("New data shape:", df.shape)
    #print(df.head(2))
    list_df.append(df)
# Out:
# realtime/2021-02-22/1613952667.ndjson
# New data shape: (28410, 13)
# realtime/2021-02-22/1613953867.ndjson
# New data shape: (27655, 13)
# realtime/2021-02-22/1613955066.ndjson
# New data shape: (41768, 13)
# realtime/2021-02-22/1613956267.ndjson
# New data shape: (38584, 13)
# realtime/2021-02-22/1613958067.ndjson
# New data shape: (41249, 13)
# realtime/2021-02-22/1613959266.ndjson
# New data shape: (28902, 13)
# realtime/2021-02-22/1613960466.ndjson
# New data shape: (24574, 13)
# realtime/2021-02-22/1613964666.ndjson
# New data shape: (37333, 13)
# realtime/2021-02-22/1613967666.ndjson
# New data shape: (38906, 13)
# realtime/2021-02-22/1613969466.ndjson
# New data shape: (29315, 13)
# realtime/2021-02-22/1613971867.ndjson
# New data shape: (40647, 13)
# realtime/2021-02-22/1613973066.ndjson
# New data shape: (41021, 13)
# realtime/2021-02-22/1613975467.ndjson
# New data shape: (26492, 13)

# %%
len(list_df)
# Out:
# 13

# %%
combined_data = pd.concat(list_df)

# %%
combined_data.shape
# Out:
# (444856, 13)

# %%
combined_data.head(10)
# Out:
#                                                 date parameter  value unit  \
# 0  {'utc': '2021-02-21T00:00:00.000Z', 'local': '...        o3  0.006  ppm
# 1  {'utc': '2021-02-21T01:00:00.000Z', 'local': '...        o3  0.006  ppm
# 2  {'utc': '2021-02-21T02:00:00.000Z', 'local': '...        o3  0.006  ppm
# 3  {'utc': '2021-02-21T03:00:00.000Z', 'local': '...        o3  0.006  ppm
# 4  {'utc': '2021-02-21T04:00:00.000Z', 'local': '...        o3  0.006  ppm
# 5  {'utc': '2021-02-21T05:00:00.000Z', 'local': '...        o3  0.006  ppm
# 6  {'utc': '2021-02-21T06:00:00.000Z', 'local': '...        o3  0.006  ppm
# 7  {'utc': '2021-02-21T07:00:00.000Z', 'local': '...        o3  0.006  ppm
# 8  {'utc': '2021-02-21T08:00:00.000Z', 'local': '...        o3  0.006  ppm
# 9  {'utc': '2021-02-21T09:00:00.000Z', 'local': '...        o3  0.006  ppm
#
#                  averagingPeriod                   location   city country  \
# 0  {'value': 1, 'unit': 'hours'}  US Diplomatic Post: Dubai  Dubai      AE
# 1  {'value': 1, 'unit': 'hours'}  US Diplomatic Post: Dubai  Dubai      AE
# 2  {'value': 1, 'unit': 'hours'}  US Diplomatic Post: Dubai  Dubai      AE
# 3  {'value': 1, 'unit': 'hours'}  US Diplomatic Post: Dubai  Dubai      AE
# 4  {'value': 1, 'unit': 'hours'}  US Diplomatic Post: Dubai  Dubai      AE
# 5  {'value': 1, 'unit': 'hours'}  US Diplomatic Post: Dubai  Dubai      AE
# 6  {'value': 1, 'unit': 'hours'}  US Diplomatic Post: Dubai  Dubai      AE
# 7  {'value': 1, 'unit': 'hours'}  US Diplomatic Post: Dubai  Dubai      AE
# 8  {'value': 1, 'unit': 'hours'}  US Diplomatic Post: Dubai  Dubai      AE
# 9  {'value': 1, 'unit': 'hours'}  US Diplomatic Post: Dubai  Dubai      AE
#
#                                       coordinates  \
# 0  {'latitude': 25.25848, 'longitude': 55.309166}
# 1  {'latitude': 25.25848, 'longitude': 55.309166}
# 2  {'latitude': 25.25848, 'longitude': 55.309166}
# 3  {'latitude': 25.25848, 'longitude': 55.309166}
# 4  {'latitude': 25.25848, 'longitude': 55.309166}
# 5  {'latitude': 25.25848, 'longitude': 55.309166}
# 6  {'latitude': 25.25848, 'longitude': 55.309166}
# 7  {'latitude': 25.25848, 'longitude': 55.309166}
# 8  {'latitude': 25.25848, 'longitude': 55.309166}
# 9  {'latitude': 25.25848, 'longitude': 55.309166}
#
#                                          attribution      sourceName  \
# 0  [{'name': 'EPA AirNow DOS', 'url': 'http://air...  StateAir_Dubai
# 1  [{'name': 'EPA AirNow DOS', 'url': 'http://air...  StateAir_Dubai
# 2  [{'name': 'EPA AirNow DOS', 'url': 'http://air...  StateAir_Dubai
# 3  [{'name': 'EPA AirNow DOS', 'url': 'http://air...  StateAir_Dubai
# 4  [{'name': 'EPA AirNow DOS', 'url': 'http://air...  StateAir_Dubai
# 5  [{'name': 'EPA AirNow DOS', 'url': 'http://air...  StateAir_Dubai
# 6  [{'name': 'EPA AirNow DOS', 'url': 'http://air...  StateAir_Dubai
# 7  [{'name': 'EPA AirNow DOS', 'url': 'http://air...  StateAir_Dubai
# 8  [{'name': 'EPA AirNow DOS', 'url': 'http://air...  StateAir_Dubai
# 9  [{'name': 'EPA AirNow DOS', 'url': 'http://air...  StateAir_Dubai
#
#    sourceType  mobile
# 0  government   False
# 1  government   False
# 2  government   False
# 3  government   False
# 4  government   False
# 5  government   False
# 6  government   False
# 7  government   False
# 8  government   False
# 9  government   False
